# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
df = pd.DataFrame({ 
    'addFromHead':   [0.234, 0.044, 0.005, 0.002, 0.002, 0.004, 0.002],
    'removeFromHead':   [0.043, 0.007, 0.002, 0.002, 0.001, 0.001, 0.002]
   })

lines = df.plot.line()

# %%
plot = df.plot()
fig = plot.get_figure()
fig.savefig("time-function.png")
