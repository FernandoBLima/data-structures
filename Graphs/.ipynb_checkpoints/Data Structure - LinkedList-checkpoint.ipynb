# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
df = pd.DataFrame({ 
    'addFromHead':   [0.407, 0.055, 0.006, 0.003, 0.002, 0.002, 0.003],
    'removeFromHead':   [0.113, 0.014, 0.004, 0.004, 0.003, 0.004, 0.006]
   })

lines = df.plot.line()
